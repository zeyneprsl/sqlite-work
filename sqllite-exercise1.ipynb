# %%
##sql alıştırmaları

# %%
import pandas as pd
# %load_ext sql
# %sql sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
##1.Orders tablosunda kaç müşteri oldugunu bulunuz.
# %sql SELECT count(*) FROM Orders
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [(196,)]

# %%
## 2. Orders tablosunda kaç tane eşsiz müşteri olduğunu bulunuz.
# %sql SELECT count(DISTINCT orders.CustomerID) FROM Orders
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [(74,)]

# %%
## 3. Customers tablosunda hangi ülkeden kaçar tane müşteri olduğunu bulunuz.
# %sql SELECT count (CustomerID) as musteri_sayisi, Country from Customers GROUP by Country
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
## 4. Müşterilerin ülkesi Brazil ya da USA olanlarını bulunuz.
# %sql SELECT * from Customers where Country in('Brazil','USA')
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
# ...

# %%
## 5. Önce ülkeye sonra şehre göre group by işlemi yapıp bu kırılımda müşteri sayısını bulunuz.
# %sql SELECT count(CustomerID),country,city from Customers GROUP By Country, City
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [(3, 'Argentina', 'Buenos Aires'),
#  (1, 'Austria', 'Graz'),
#  (1, 'Austria', 'Salzburg'),
#  (1, 'Belgium', 'Bruxelles'),
#  (1, 'Belgium', 'Charleroi'),
#  (1, 'Brazil', 'Campinas'),
#  (1, 'Brazil', 'Resende'),
#  (3, 'Brazil', 'Rio de Janeiro'),
#  (4, 'Brazil', 'São Paulo'),
#  (1, 'Canada', 'Montréal'),
#  (1, 'Canada', 'Tsawassen'),
#  (1, 'Canada', 'Vancouver'),
#  (1, 'Denmark', 'København'),
#  (1, 'Denmark', 'Århus'),
#  (1, 'Finland', 'Helsinki'),
#  (1, 'Finland', 'Oulu'),
#  (1, 'France', 'Lille'),
#  (1, 'France', 'Lyon'),
#  (1, 'France', 'Marseille'),
#  (2, 'France', 'Nantes'),
#  (2, 'France', 'Paris'),
#  (1, 'France', 'Reims'),
#  (1, 'France', 'Strasbourg'),
#  (1, 'France', 'Toulouse'),
#  (1, 'France', 'Versailles'),
#  (1, 'Germany', 'Aachen'),
#  (1, 'Germany', 'Berlin'),
#  (1, 'Germany', 'Brandenburg'),
#  (1, 'Germany', 'Cunewalde'),
#  (1, 'Germany', 'Frankfurt a.M.'),
# ...

# %%
## 6. Müşterileri adreslerinin herhangi bir yerinde "da" ifadesi geçen tüm adresleri bulunuz.
# %sql SELECT * from Customers where Address like '%da%'
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db

# %%
## 7. Germany-Berlin'de yaşayan müşteri/müşterilerin isimleri nelerdir?
# %sql SELECT CustomerName, Country,city from Customers where Country='Berlin' and  City='Berlin'
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# []

# %%
## 8. Canada'da yaşayıp isimlerinde "in" ifadesi geçen müşteri/müşterileri bulunuz.
# %sql SELECT CustomerName, Country from Customers where Country='Canada' and  CustomerName like '%in%'
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [('Laughing Bacchus Wine Cellars', 'Canada')]

# %%
## 9. Fiyatı 40 TL ile 90 TL arasında olan ürünlerin isimleri ve fiyatları nelerdir?
# %sql SELECT ProductName ,price from Products WHERE price >=40 and price <=90
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [('Northwoods Cranberry Sauce', 40),
#  ('Genen Shouyu', 43),
#  ('Carnarvon Tigers', 62),
#  ('Teatime Chocolate Biscuits', 43),
#  ("Sir Rodney's Marmalade", 81),
#  ('Guaraná Fantástica', 43),
#  ('Schoggi Schokolade', 43),
#  ('Rössle Sauerkraut', 45),
#  ('Geitost', 43),
#  ('Boston Crab Meat', 43),
#  ('Ipoh Coffee', 46),
#  ('Røgede sild', 43),
#  ('Zaanse koeken', 43),
#  ('Manjimup Dried Apples', 53),
#  ('Ravioli Angelo', 43),
#  ('Raclette Courdavault', 55),
#  ("Sirop d'érable", 43),
#  ('Tarte au sucre', 49),
#  ('Vegie-spread', 43),
#  ('Louisiana Fiery Hot Pepper Sauce', 43),
#  ('Scottish Longbreads', 45)]

# %%
## 10. Fiyatı 30 TL'den büyük olan ürünlerin isimlerini, 
#fiyatlarini ve fiyatlarinin karesini bulunuz ve
#tüm değişkenlerin isimlendirmelerini aşağıdaki şekilde yapınız urun ismi, urun_fiyati, ürün_fiyatinin_karesi
# %sql SELECT ProductName as urun_ismi ,price as  urun_fiyati , price*2 as fiyat_karesi from Products WHERE price >30
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Done.
# [('Northwoods Cranberry Sauce', 40, 80),
#  ('Mishi Kobe Niku', 97, 194),
#  ('Ikura', 31, 62),
#  ('Queso Manchego La Pastora', 38, 76),
#  ('Genen Shouyu', 43, 86),
#  ('Alice Mutton', 39, 78),
#  ('Carnarvon Tigers', 62, 124),
#  ('Teatime Chocolate Biscuits', 43, 86),
#  ("Sir Rodney's Marmalade", 81, 162),
#  ('Guaraná Fantástica', 43, 86),
#  ('Gumbär Gummibärchen', 31, 62),
#  ('Schoggi Schokolade', 43, 86),
#  ('Rössle Sauerkraut', 45, 90),
#  ('Thüringer Rostbratwurst', 123, 246),
#  ('Gorgonzola Telino', 435, 870),
#  ('Mascarpone Fabioli', 32, 64),
#  ('Geitost', 43, 86),
#  ('Côte de Blaye', 263, 526),
#  ('Boston Crab Meat', 43, 86),
#  ('Ipoh Coffee', 46, 92),
#  ('Røgede sild', 43, 86),
#  ('Zaanse koeken', 43, 86),
#  ('Manjimup Dried Apples', 53, 106),
#  ('Perth Pasties', 32, 64),
#  ('Gnocchi di nonna Alice', 38, 76),
#  ('Ravioli Angelo', 43, 86),
#  ('Raclette Courdavault', 55, 110),
# ...
