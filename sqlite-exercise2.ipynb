# %%
import pandas as pd
# %load_ext sql
# %sql sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
##--11. Products tablosundaki CategoryID’leri var ama numara seklinde bu katagorileri isimleri nelerdir?
# %sql SELECT * FROM Products LEFT JOIN Categories on Products.CategoryID = Categories.CategoryID;
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
# ...

# %%
#12. beverages ürün kategorisindeki ürünlerin fiyat ortalaması nedir?
# %sql SELECT avg(Price) FROM Products LEFT JOIN Categories on Products.CategoryID = categories.CategoryID  where CategoryName='Beverages'
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [(42.75,)]

# %%
#13. USA'de yaşayan müşterilerin kazandırdığı toplam kazancı bulunuz.
# %sql SELECT SUM(p.Price) FROM Orders o LEFT JOIN OrderDetails od on o.OrderID = od.OrderID  LEFT JOIN Products p on od.ProductID = p.ProductID  LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID where cu.Country = 'USA';
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [(3762,)]

# %%
##14. Products tablosundaki CategoryID'lerin isimlerini bulunuz ve sonrasında kategori başına ortalama ürün fiyatını gösteriniz.
# %sql SELECT AVG(Price), CategoryName FROM Products  LEFT JOIN Categories on Products.CategoryID = Categories.CategoryID GROUP BY CategoryName;
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [(42.75, 'Beverages'),
#  (28.25, 'Condiments'),
#  (33.76923076923077, 'Confections'),
#  (74.9, 'Dairy Products'),
#  (23.571428571428573, 'Grains/Cereals'),
#  (55.166666666666664, 'Meat/Poultry'),
#  (32.2, 'Produce'),
#  (26.5, 'Seafood')]

# %%
#15. Çalışanları (EmployeeID) isimleri ile birlikte yaptıkları toplam satışlara göre sıralayınız.
# %sql SELECT em.FirstName, SUM(p.Price) toplam_satis  FROM Orders o  LEFT JOIN OrderDetails od on o.OrderID = od.OrderID  LEFT JOIN Products p on od.ProductID = p.ProductID  LEFT JOIN Employees em on o.EmployeeID = em.EmployeeID  GROUP BY o.EmployeeID  ORDER BY toplam_satis DESC;
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [('Margaret', 5515),
#  ('Nancy', 4353),
#  ('Janet', 3048),
#  ('Michael', 2981),
#  ('Laura', 2380),
#  ('Robert', 1852),
#  ('Andrew', 1550),
#  ('Steven', 1408),
#  ('Anne', 520)]

# %%
#16. Germany'dan verilen siparişlerin kategorilerine göre ortalama fiyatları nelerdir?
# %sql SELECT ca.CategoryName ,avg(p.price)  FROM Orders o LEFT JOIN OrderDetails od on o.OrderID = od.OrderID LEFT JOIN Products p on od.ProductID = p.ProductID LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID WHERE cu.Country = 'Germany' GROUP BY CategoryName;
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [('Beverages', 20.5),
#  ('Condiments', 34.0),
#  ('Confections', 40.0),
#  ('Dairy Products', 151.64705882352942),
#  ('Grains/Cereals', 22.142857142857142),
#  ('Meat/Poultry', 30.2),
#  ('Produce', 30.75),
#  ('Seafood', 27.09090909090909)]

# %%
#17. Almanya ya da USA'den verilen siparişlerin kategorilerine göre ortalama fiyatları nelerdir?
# %sql SELECT ca.CategoryName, AVG(p.Price)  FROM Orders o LEFT JOIN OrderDetails od on o.OrderId = od.OrderId LEFT JOIN Products p on od.ProductID = p.ProductID  LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID WHERE cu.Country = 'Germany' OR cu.Country = 'USA' GROUP BY CategoryName;
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [('Beverages', 29.88888888888889),
#  ('Condiments', 34.72727272727273),
#  ('Confections', 39.92307692307692),
#  ('Dairy Products', 131.75862068965517),
#  ('Grains/Cereals', 29.846153846153847),
#  ('Meat/Poultry', 46.75),
#  ('Produce', 28.625),
#  ('Seafood', 25.6)]

# %%
 ##18. Haziran Temmuz Ağustos aylarında verilen siparişlerin ortalama fiyatı nedir?
# %sql SELECT AVG(Products.Price) FROM Products LEFT JOIN OrderDetails on OrderDetails.ProductID = products.ProductID LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID WHERE OrderDate like '%07%' or OrderDate like '%08%' or OrderDate like '%09%';
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [(39.71891891891892,)]

# %%
#19. Müşterilerin 1997 yılına ait siparişlerinin maksimum miktarlarını bulup müşterilerin isimleri ile birlikte büyükten küçüğe sıralayınız.
# %sql SELECT CustomerName, MAX(Price) maks FROM Products LEFT JOIN OrderDetails on Products.ProductID = OrderDetails.ProductID LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID LEFT JOIN Customers on Customers.CustomerID = Orders.CustomerID WHERE OrderDate like '%1997%' GROUP BY CustomerName ORDER BY maks DESC;
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [('Gourmet Lanchonetes', 435),
#  ('Simons bistro', 263),
#  ('Mère Paillarde', 263),
#  ('Save-a-lot Markets', 123),
#  ('Eastern Connection', 123),
#  ('Wellington Importadora', 97),
#  ('Ernst Handel', 55),
#  ('Bottom-Dollar Marketse', 55),
#  ("La maison d'Asie", 49),
#  ('Folies gourmandes', 49),
#  ('Reggiani Caseifici', 45),
#  ('Queen Cozinha', 45),
#  ('Wartian Herkku', 43),
#  ('Toms Spezialitäten', 43),
#  ('Rattlesnake Canyon Grocery', 43),
#  ('Que Delícia', 43),
#  ('QUICK-Stop', 43),
#  ('Old World Delicatessen', 43),
#  ('Hungry Owl All-Night Grocers', 43),
#  ('Hungry Coyote Import Store', 43),
#  ('Familia Arquibaldo', 43),
#  ('Princesa Isabel Vinhoss', 38),
#  ('Galería del gastrónomo', 38),
#  ('Blondel père et fils', 38),
#  ('Richter Supermarkt', 36),
#  ('Ottilies Käseladen', 36),
# ...

# %%
#20. Sipariş yılı 1997 olan siparişleri alan çalışanları sipariş alma sayılarına göre sıralayınız.
# %sql SELECT COUNT(*) n, em.FirstName FROM Orders LEFT JOIN Employees em on Orders.EmployeeID = em.EmployeeID WHERE OrderDate like '%1997%' GROUP BY em.FirstName ORDER by n DESC;
# Out:
#  * sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.db
#    sqlite:///C:\Users\Zeynep\OneDrive\Belgeler\veri_tabanı-sqlite.sqbpro
# Done.
# [(13, 'Janet'),
#  (9, 'Margaret'),
#  (8, 'Laura'),
#  (4, 'Andrew'),
#  (3, 'Robert'),
#  (3, 'Nancy'),
#  (3, 'Michael'),
#  (1, 'Anne')]
